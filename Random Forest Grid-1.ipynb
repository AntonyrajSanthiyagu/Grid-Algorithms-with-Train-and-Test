# %%
#importing the Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
#from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['squared_error', 'poisson', 'absolute_error', 'friedman_mse'],
'max_features': [None,'sqrt','log2'],
'n_estimators':[10,100]}
grid = GridSearchCV(RandomForestRegressor(),param_grid,refit = True,verbose= 3,n_jobs=-1)
# fitting the model for grid search
grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anaconda 3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'poisson',
#                                        'absolute_error', 'friedman_mse'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test)
# print classification report
from sklearn.metrics import r2_score
r_score=r2_score(Y_test,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 100}: 0.8725856580903999

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.374919      0.145952         0.008563        0.008081
# 1        1.067565      0.084933         0.038312        0.009612
# 2        0.094123      0.005699         0.006850        0.003654
# 3        0.780830      0.008485         0.029429        0.005556
# 4        0.102668      0.022206         0.007627        0.007009
# 5        0.722112      0.039203         0.029807        0.007019
# 6        0.113611      0.002285         0.005233        0.004367
# 7        1.041656      0.137980         0.036501        0.004825
# 8        0.333747      0.314602         0.008073        0.004037
# 9        0.889093      0.084705         0.026515        0.008229
# 10       0.093848      0.007292         0.008075        0.004038
# 11       0.951259      0.253010         0.027045        0.009354
# 12       0.375656      0.027958         0.012306        0.006898
# 13       3.529649      0.145072         0.042480        0.020995
# 14       0.241349      0.036380         0.003727        0.007454
# 15       2.094655      0.115320         0.028542        0.009357
# 16       0.223846      0.014251         0.007876        0.007014
# 17       2.121186      0.095546         0.030910        0.006243
# 18       0.109500      0.016253         0.003142        0.006284
# 19       0.939023      0.043782         0.025402        0.003354
# 20       0.342873      0.415426         0.007585        0.005181
# 21       0.786171      0.023156         0.042324        0.008908
# 22       0.106853      0.040758         0.011133        0.006608
# 23       0.651887      0.086302         0.024384        0.005052
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               None                 10
# 1    squared_error               None                100
# 2    squared_error               sqrt                 10
# 3    squared_error               sqrt                100
# 4    squared_error               log2                 10
# 5    squared_error               log2                100
# 6          poisson               None                 10
# 7          poisson               None                100
# 8          poisson               sqrt                 10
# 9          poisson               sqrt                100
# 10         poisson               log2                 10
# 11         poisson               log2                100
# 12  absolute_error               None                 10
# 13  absolute_error               None                100
# 14  absolute_error               sqrt                 10
# 15  absolute_error               sqrt                100
# 16  absolute_error               log2                 10
# 17  absolute_error               log2                100
# 18    friedman_mse               None                 10
# 19    friedman_mse               None                100
# 20    friedman_mse               sqrt                 10
# 21    friedman_mse               sqrt                100
# 22    friedman_mse               log2                 10
# 23    friedman_mse               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.857901
# 1   {'criterion': 'squared_error', 'max_features':...           0.862340
# 2   {'criterion': 'squared_error', 'max_features':...           0.840105
# 3   {'criterion': 'squared_error', 'max_features':...           0.861522
# 4   {'criterion': 'squared_error', 'max_features':...           0.835564
# 5   {'criterion': 'squared_error', 'max_features':...           0.856823
# 6   {'criterion': 'poisson', 'max_features': None,...           0.852280
# 7   {'criterion': 'poisson', 'max_features': None,...           0.865621
# 8   {'criterion': 'poisson', 'max_features': 'sqrt...           0.848262
# 9   {'criterion': 'poisson', 'max_features': 'sqrt...           0.857134
# 10  {'criterion': 'poisson', 'max_features': 'log2...           0.832334
# 11  {'criterion': 'poisson', 'max_features': 'log2...           0.868613
# 12  {'criterion': 'absolute_error', 'max_features'...           0.833867
# 13  {'criterion': 'absolute_error', 'max_features'...           0.844319
# 14  {'criterion': 'absolute_error', 'max_features'...           0.834911
# 15  {'criterion': 'absolute_error', 'max_features'...           0.861139
# 16  {'criterion': 'absolute_error', 'max_features'...           0.845610
# 17  {'criterion': 'absolute_error', 'max_features'...           0.862609
# 18  {'criterion': 'friedman_mse', 'max_features': ...           0.853412
# 19  {'criterion': 'friedman_mse', 'max_features': ...           0.860093
# 20  {'criterion': 'friedman_mse', 'max_features': ...           0.845749
# 21  {'criterion': 'friedman_mse', 'max_features': ...           0.863988
# 22  {'criterion': 'friedman_mse', 'max_features': ...           0.860392
# 23  {'criterion': 'friedman_mse', 'max_features': ...           0.857188
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.740328           0.812341           0.786402
# 1            0.773039           0.812292           0.789654
# 2            0.774292           0.799944           0.814222
# 3            0.786291           0.804042           0.826316
# 4            0.758691           0.793824           0.814468
# 5            0.784919           0.810217           0.826551
# 6            0.771687           0.805078           0.779686
# 7            0.776952           0.815393           0.800054
# 8            0.773195           0.797149           0.779051
# 9            0.798311           0.814498           0.822640
# 10           0.762902           0.811344           0.808399
# 11           0.797852           0.805179           0.821031
# 12           0.770965           0.785806           0.788891
# 13           0.779009           0.797485           0.805934
# 14           0.780094           0.777464           0.808462
# 15           0.795607           0.807443           0.819532
# 16           0.756313           0.795701           0.789134
# 17           0.796968           0.810636           0.815159
# 18           0.748862           0.810724           0.777519
# 19           0.759356           0.815892           0.799098
# 20           0.790720           0.766245           0.805191
# 21           0.794004           0.811399           0.826748
# 22           0.740313           0.760366           0.803741
# 23           0.793485           0.810451           0.823063
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.762488         0.791892        0.040814               20
# 1            0.768164         0.801098        0.034290               10
# 2            0.745110         0.794735        0.032698               13
# 3            0.773093         0.810253        0.031241                7
# 4            0.757883         0.792086        0.030592               19
# 5            0.767911         0.809284        0.031191                8
# 6            0.760724         0.793891        0.032647               14
# 7            0.766591         0.804922        0.034840                9
# 8            0.770706         0.793672        0.028819               15
# 9            0.773561         0.813229        0.027619                1
# 10           0.746672         0.792330        0.032158               18
# 11           0.769206         0.812376        0.032754                2
# 12           0.743668         0.784639        0.029354               24
# 13           0.759560         0.797262        0.028440               12
# 14           0.765389         0.793264        0.025162               16
# 15           0.774465         0.811637        0.028876                5
# 16           0.752697         0.787891        0.033555               22
# 17           0.770790         0.811232        0.029981                6
# 18           0.767986         0.791701        0.036794               21
# 19           0.767603         0.800408        0.036236               11
# 20           0.754742         0.792529        0.031983               17
# 21           0.763966         0.812021        0.033322                3
# 22           0.759024         0.784767        0.043159               23
# 23           0.775810         0.811999        0.027638                4
